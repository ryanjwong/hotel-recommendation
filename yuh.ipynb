# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading in Data

# %%
hotel_review = pd.read_csv('Hotel_Reviews.csv')
hotel_review_sample = hotel_review.sample(frac=0.2, random_state = 42)
hotel_review_sample.to_csv("hotel_review_sample.csv", index = False)

# %%
hotel_prices = pd.read_csv('booking_bcn1.csv', index_col = 0)

# %% [markdown]
# Checking to see how many hotel names match

# %%
hotel_review_sample['name_processed'] = hotel_review_sample['Hotel_Name'].str.strip().str.lower()

drop_cols = [
    'Hotel_Name'
]

hotel_review_sample = hotel_review_sample.drop(columns=drop_cols)

# %%
hotel_prices['name_processed'] = hotel_prices['Hotels'].str.lower().str.split()

drop_cols = [
    'Hotels'
]

hotel_prices = hotel_prices.drop(columns=drop_cols)

# %%
hotel_prices['name_processed'] = hotel_prices['name_processed'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
matching_hotels = set(hotel_prices['name_processed']).intersection(set(hotel_review_sample['name_processed']))

# Count the number of matches
num_matches = len(matching_hotels)

print(f"Number of matching hotel names: {num_matches}")
# Out:
# Number of matching hotel names: 96

# %% [markdown]
# Getting rid of columns we don't need

# %%
hotel_review_sample.columns
# Out:
# Index(['Hotel_Address', 'Additional_Number_of_Scoring', 'Review_Date',
#        'Average_Score', 'Reviewer_Nationality', 'Negative_Review',
#        'Review_Total_Negative_Word_Counts', 'Total_Number_of_Reviews',
#        'Positive_Review', 'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score', 'Tags',
#        'days_since_review', 'lat', 'lng', 'name_processed'],
#       dtype='object')

# %%
drop_cols = [
    'Hotel_Address', 
    'Additional_Number_of_Scoring', 
    'Review_Date', 
    'Average_Score', 
    'Reviewer_Nationality', 
    'Total_Number_of_Reviews', 
    'Tags', 
    'days_since_review', 
    'lat', 
    'lng'
]

hotel_review_sample = hotel_review_sample.drop(columns=drop_cols)

# %%
merged_df = hotel_review_sample.merge(
    hotel_prices, on="name_processed", how="inner"
)

# %%
# merged_df
merged_df.columns
# Out:
# Index(['Negative_Review', 'Review_Total_Negative_Word_Counts',
#        'Positive_Review', 'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score',
#        'name_processed', 'Prices', 'Descriptions', 'Full_Descriptions'],
#       dtype='object')

# %%
print(merged_df.isna().sum())  # See missing values
# Out:
# Negative_Review                               0
# Review_Total_Negative_Word_Counts             0
# Positive_Review                               0
# Review_Total_Positive_Word_Counts             0
# Total_Number_of_Reviews_Reviewer_Has_Given    0
# Reviewer_Score                                0
# name_processed                                0
# Prices                                        0
# Descriptions                                  0
# Full_Descriptions                             0
# dtype: int64

# %%
merged_df = merged_df[['name_processed']+ ['Negative_Review', 'Review_Total_Negative_Word_Counts',
       'Positive_Review', 'Review_Total_Positive_Word_Counts',
       'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score',
        'Prices', 'Descriptions', 'Full_Descriptions']]

# %%
merged_df
# Out:
#                     name_processed  \
# 0                   room mate anna
# 1           hotel barcelona center
# 2         hotel barcelona catedral
# 3     petit palace boqueria garden
# 4              hotel ronda lesseps
# ...                            ...
# 6003     capri by fraser barcelona
# 6004  petit palace boqueria garden
# 6005            hotel villa emilia
# 6006           olivia balmes hotel
# 6007       catalonia eixample 1864
#
#                                         Negative_Review  \
# 0                                    Nothing to dislike
# 1                                           No Negative
# 2      Due to the location and it being a very touri...
# 3                                           No Negative
# 4      Semi transparent wall of bathroom It cause un...
# ...                                                 ...
# 6003   There was a faint sewage smell in the bathroo...
# 6004   The streets were very noisy from 3 6am No cof...
# 6005   The room was ready early when we arrived afte...
# 6006                                        No Negative
# 6007   The pool was a bit small and there were not v...
#
#       Review_Total_Negative_Word_Counts  \
# 0                                     4
# 1                                     0
# 2                                    31
# 3                                     0
# 4                                    14
# ...                                 ...
# 6003                                 24
# 6004                                 18
# 6005                                 21
# 6006                                  0
# 6007                                 21
#
#                                         Positive_Review  \
# 0      Location Culture bars and restaurants Transpo...
# 1      The hotel was in a great spot near to everyth...
# 2      We had such a great experience here The staff...
# 3      Free coffee if wanted during breakfast withou...
# 4      Easy to reach from and to airport by metro wi...
# ...                                                 ...
# 6003   Lovely studio and apartment hotel with large ...
# 6004                                    Great location
# 6005   Very nice hotel and extremely helpful and fri...
# 6006   Staff were lovely very useful The shower was ...
# 6007   The staff was extremely helpful and friendly ...
#
#       Review_Total_Positive_Word_Counts  \
# 0                                    13
# 1                                    29
# 2                                   138
# 3                                    41
# 4                                    41
# ...                                 ...
# 6003                                 43
# 6004                                  4
# 6005                                 10
# 6006                                 29
# 6007                                 18
#
#       Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  Prices  \
# 0                                              2             9.6  1418.0
# 1                                              7             8.8  1584.0
# 2                                              1            10.0  2259.0
# 3                                              1             7.9  2068.0
# 4                                              4             7.9  1352.0
# ...                                          ...             ...     ...
# 6003                                          13             9.6  1347.0
# 6004                                          10             7.9  2068.0
# 6005                                           1            10.0  1607.0
# 6006                                          15             9.2  1904.0
# 6007                                           1             9.6  1314.0
#
#                      Descriptions  \
# 0                    1 double bed
# 1              Multiple bed types
# 2        1 extra-large double bed
# 3     Beds: 1 double or 2 singles
# 4                    1 double bed
# ...                           ...
# 6003  Beds: 1 double or 2 singles
# 6004  Beds: 1 double or 2 singles
# 6005  Beds: 1 double or 2 singles
# 6006  Beds: 1 double or 2 singles
# 6007  Beds: 1 double or 2 singles
#
#                                       Full_Descriptions
# 0     Featuring a seasonal rooftop plunge pool with ...
# 1     Barcelona Center is 400 metres from Barcelona’...
# 2     There is a gym and a rooftop chill-out terrace...
# 3     The Petit Palace Boqueria Garden is set in a h...
# 4     The Hotel Ronda Lesseps is a quiet and familia...
# ...                                                 ...
# 6003  This motorcycle-friendly hotel is 3 Metro stop...
# 6004  The Petit Palace Boqueria Garden is set in a h...
# 6005  This stylish design hotel is located 150 metre...
# 6006  Offering an outdoor swimming pool, Olivia Balm...
# 6007  Located in Barcelona’s Eixample district, this...
#
# [6008 rows x 10 columns]

# %%
merged_df['Prices'] = merged_df['Prices'].str.replace('€', '', regex=True).str.replace(',', '', regex=True).str.strip().astype(float)

# %%
merged_df.columns
# Out:
# Index(['Negative_Review', 'Review_Total_Negative_Word_Counts',
#        'Positive_Review', 'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score',
#        'name_processed', 'Prices', 'Descriptions', 'Full_Descriptions'],
#       dtype='object')

# %%
merged_df
# Out:
#                     name_processed  \
# 0                   room mate anna
# 1           hotel barcelona center
# 2         hotel barcelona catedral
# 3     petit palace boqueria garden
# 4              hotel ronda lesseps
# ...                            ...
# 6003     capri by fraser barcelona
# 6004  petit palace boqueria garden
# 6005            hotel villa emilia
# 6006           olivia balmes hotel
# 6007       catalonia eixample 1864
#
#                                         Negative_Review  \
# 0                                    Nothing to dislike
# 1                                           No Negative
# 2      Due to the location and it being a very touri...
# 3                                           No Negative
# 4      Semi transparent wall of bathroom It cause un...
# ...                                                 ...
# 6003   There was a faint sewage smell in the bathroo...
# 6004   The streets were very noisy from 3 6am No cof...
# 6005   The room was ready early when we arrived afte...
# 6006                                        No Negative
# 6007   The pool was a bit small and there were not v...
#
#       Review_Total_Negative_Word_Counts  \
# 0                                     4
# 1                                     0
# 2                                    31
# 3                                     0
# 4                                    14
# ...                                 ...
# 6003                                 24
# 6004                                 18
# 6005                                 21
# 6006                                  0
# 6007                                 21
#
#                                         Positive_Review  \
# 0      Location Culture bars and restaurants Transpo...
# 1      The hotel was in a great spot near to everyth...
# 2      We had such a great experience here The staff...
# 3      Free coffee if wanted during breakfast withou...
# 4      Easy to reach from and to airport by metro wi...
# ...                                                 ...
# 6003   Lovely studio and apartment hotel with large ...
# 6004                                    Great location
# 6005   Very nice hotel and extremely helpful and fri...
# 6006   Staff were lovely very useful The shower was ...
# 6007   The staff was extremely helpful and friendly ...
#
#       Review_Total_Positive_Word_Counts  \
# 0                                    13
# 1                                    29
# 2                                   138
# 3                                    41
# 4                                    41
# ...                                 ...
# 6003                                 43
# 6004                                  4
# 6005                                 10
# 6006                                 29
# 6007                                 18
#
#       Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  Prices  \
# 0                                              2             9.6  1418.0
# 1                                              7             8.8  1584.0
# 2                                              1            10.0  2259.0
# 3                                              1             7.9  2068.0
# 4                                              4             7.9  1352.0
# ...                                          ...             ...     ...
# 6003                                          13             9.6  1347.0
# 6004                                          10             7.9  2068.0
# 6005                                           1            10.0  1607.0
# 6006                                          15             9.2  1904.0
# 6007                                           1             9.6  1314.0
#
#                      Descriptions  \
# 0                    1 double bed
# 1              Multiple bed types
# 2        1 extra-large double bed
# 3     Beds: 1 double or 2 singles
# 4                    1 double bed
# ...                           ...
# 6003  Beds: 1 double or 2 singles
# 6004  Beds: 1 double or 2 singles
# 6005  Beds: 1 double or 2 singles
# 6006  Beds: 1 double or 2 singles
# 6007  Beds: 1 double or 2 singles
#
#                                       Full_Descriptions
# 0     Featuring a seasonal rooftop plunge pool with ...
# 1     Barcelona Center is 400 metres from Barcelona’...
# 2     There is a gym and a rooftop chill-out terrace...
# 3     The Petit Palace Boqueria Garden is set in a h...
# 4     The Hotel Ronda Lesseps is a quiet and familia...
# ...                                                 ...
# 6003  This motorcycle-friendly hotel is 3 Metro stop...
# 6004  The Petit Palace Boqueria Garden is set in a h...
# 6005  This stylish design hotel is located 150 metre...
# 6006  Offering an outdoor swimming pool, Olivia Balm...
# 6007  Located in Barcelona’s Eixample district, this...
#
# [6008 rows x 10 columns]

# %% [markdown]
# # P(Hotel Recommendation | Sentiment, Reviewer Score, Price)
# Converting observations into probabilities and generating CPTs

# %%
# Labeling sentiment based on positive/negative word count
def classify_sentiment(row):
    if row['Review_Total_Positive_Word_Counts'] > row['Review_Total_Negative_Word_Counts']:
        return 'Positive'
    elif row['Review_Total_Positive_Word_Counts'] < row['Review_Total_Negative_Word_Counts']:
        return 'Negative'
    else:
        return 'Neutral'

# Apply function to create sentiment column
merged_df['Sentiment'] = merged_df.apply(classify_sentiment, axis=1)

# %%
np.mean(merged_df['Reviewer_Score'])
# Out:
# np.float64(8.502496671105193)

# %%
# Define recommendation criteria
def recommend_hotel(row):
    if row['Reviewer_Score'] >= 8 and row['Sentiment'] == 'Positive':
        return 1  # Recommend
    else:
        return 0  # Do not recommend

# Apply function
merged_df['Hotel_Recommendation'] = merged_df.apply(recommend_hotel, axis=1)

# %%
merged_df['Hotel_Recommendation'].value_counts()
# Out:
# Hotel_Recommendation
# 0    3182
# 1    2826
# Name: count, dtype: int64

# %%
merged_df
# Out:
#                     name_processed  \
# 0                   room mate anna
# 1           hotel barcelona center
# 2         hotel barcelona catedral
# 3     petit palace boqueria garden
# 4              hotel ronda lesseps
# ...                            ...
# 6003     capri by fraser barcelona
# 6004  petit palace boqueria garden
# 6005            hotel villa emilia
# 6006           olivia balmes hotel
# 6007       catalonia eixample 1864
#
#                                         Negative_Review  \
# 0                                    Nothing to dislike
# 1                                           No Negative
# 2      Due to the location and it being a very touri...
# 3                                           No Negative
# 4      Semi transparent wall of bathroom It cause un...
# ...                                                 ...
# 6003   There was a faint sewage smell in the bathroo...
# 6004   The streets were very noisy from 3 6am No cof...
# 6005   The room was ready early when we arrived afte...
# 6006                                        No Negative
# 6007   The pool was a bit small and there were not v...
#
#       Review_Total_Negative_Word_Counts  \
# 0                                     4
# 1                                     0
# 2                                    31
# 3                                     0
# 4                                    14
# ...                                 ...
# 6003                                 24
# 6004                                 18
# 6005                                 21
# 6006                                  0
# 6007                                 21
#
#                                         Positive_Review  \
# 0      Location Culture bars and restaurants Transpo...
# 1      The hotel was in a great spot near to everyth...
# 2      We had such a great experience here The staff...
# 3      Free coffee if wanted during breakfast withou...
# 4      Easy to reach from and to airport by metro wi...
# ...                                                 ...
# 6003   Lovely studio and apartment hotel with large ...
# 6004                                    Great location
# 6005   Very nice hotel and extremely helpful and fri...
# 6006   Staff were lovely very useful The shower was ...
# 6007   The staff was extremely helpful and friendly ...
#
#       Review_Total_Positive_Word_Counts  \
# 0                                    13
# 1                                    29
# 2                                   138
# 3                                    41
# 4                                    41
# ...                                 ...
# 6003                                 43
# 6004                                  4
# 6005                                 10
# 6006                                 29
# 6007                                 18
#
#       Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  Prices  \
# 0                                              2             9.6  1418.0
# 1                                              7             8.8  1584.0
# 2                                              1            10.0  2259.0
# 3                                              1             7.9  2068.0
# 4                                              4             7.9  1352.0
# ...                                          ...             ...     ...
# 6003                                          13             9.6  1347.0
# 6004                                          10             7.9  2068.0
# 6005                                           1            10.0  1607.0
# 6006                                          15             9.2  1904.0
# 6007                                           1             9.6  1314.0
#
#                      Descriptions  \
# 0                    1 double bed
# 1              Multiple bed types
# 2        1 extra-large double bed
# 3     Beds: 1 double or 2 singles
# 4                    1 double bed
# ...                           ...
# 6003  Beds: 1 double or 2 singles
# 6004  Beds: 1 double or 2 singles
# 6005  Beds: 1 double or 2 singles
# 6006  Beds: 1 double or 2 singles
# 6007  Beds: 1 double or 2 singles
#
#                                       Full_Descriptions Sentiment  \
# 0     Featuring a seasonal rooftop plunge pool with ...  Positive
# 1     Barcelona Center is 400 metres from Barcelona’...  Positive
# 2     There is a gym and a rooftop chill-out terrace...  Positive
# 3     The Petit Palace Boqueria Garden is set in a h...  Positive
# 4     The Hotel Ronda Lesseps is a quiet and familia...  Positive
# ...                                                 ...       ...
# 6003  This motorcycle-friendly hotel is 3 Metro stop...  Positive
# 6004  The Petit Palace Boqueria Garden is set in a h...  Negative
# 6005  This stylish design hotel is located 150 metre...  Negative
# 6006  Offering an outdoor swimming pool, Olivia Balm...  Positive
# 6007  Located in Barcelona’s Eixample district, this...  Negative
#
#       Hotel_Recommendation
# 0                        1
# 1                        1
# 2                        1
# 3                        0
# 4                        0
# ...                    ...
# 6003                     1
# 6004                     0
# 6005                     0
# 6006                     1
# 6007                     0
#
# [6008 rows x 12 columns]

# %%
merged_df['Prices'].max()
# Out:
# np.float64(17266.0)

# %%
merged_df['Prices'].min()
# Out:
# np.float64(1005.0)

# %%
merged_df['Prices'].mean()
# Out:
# np.float64(2042.6183422103861)

# %%
# creating bins and labels for Reviewer Score and Prices
reviewer_bins = [0, 5, 8, 10]  
reviewer_labels = ['Low', 'Medium', 'High']

price_bins = [1000, 2043, float('inf')]
price_labels = ['Affordable', 'Expensive']


merged_df['Reviewer_Score_Binned'] = pd.cut(merged_df['Reviewer_Score'], bins=reviewer_bins, labels=reviewer_labels, include_lowest=True)
merged_df['Price_Binned'] = pd.cut(merged_df['Prices'], bins=price_bins, labels=price_labels, include_lowest=True)


merged_df[['Reviewer_Score', 'Reviewer_Score_Binned', 'Prices', 'Price_Binned']].head()
# Out:
#    Reviewer_Score Reviewer_Score_Binned  Prices Price_Binned
# 0             9.6                  High  1418.0   Affordable
# 1             8.8                  High  1584.0   Affordable
# 2            10.0                  High  2259.0    Expensive
# 3             7.9                Medium  2068.0    Expensive
# 4             7.9                Medium  1352.0   Affordable

# %%
merged_df
# Out:
#                     name_processed  \
# 0                   room mate anna
# 1           hotel barcelona center
# 2         hotel barcelona catedral
# 3     petit palace boqueria garden
# 4              hotel ronda lesseps
# ...                            ...
# 6003     capri by fraser barcelona
# 6004  petit palace boqueria garden
# 6005            hotel villa emilia
# 6006           olivia balmes hotel
# 6007       catalonia eixample 1864
#
#                                         Negative_Review  \
# 0                                    Nothing to dislike
# 1                                           No Negative
# 2      Due to the location and it being a very touri...
# 3                                           No Negative
# 4      Semi transparent wall of bathroom It cause un...
# ...                                                 ...
# 6003   There was a faint sewage smell in the bathroo...
# 6004   The streets were very noisy from 3 6am No cof...
# 6005   The room was ready early when we arrived afte...
# 6006                                        No Negative
# 6007   The pool was a bit small and there were not v...
#
#       Review_Total_Negative_Word_Counts  \
# 0                                     4
# 1                                     0
# 2                                    31
# 3                                     0
# 4                                    14
# ...                                 ...
# 6003                                 24
# 6004                                 18
# 6005                                 21
# 6006                                  0
# 6007                                 21
#
#                                         Positive_Review  \
# 0      Location Culture bars and restaurants Transpo...
# 1      The hotel was in a great spot near to everyth...
# 2      We had such a great experience here The staff...
# 3      Free coffee if wanted during breakfast withou...
# 4      Easy to reach from and to airport by metro wi...
# ...                                                 ...
# 6003   Lovely studio and apartment hotel with large ...
# 6004                                    Great location
# 6005   Very nice hotel and extremely helpful and fri...
# 6006   Staff were lovely very useful The shower was ...
# 6007   The staff was extremely helpful and friendly ...
#
#       Review_Total_Positive_Word_Counts  \
# 0                                    13
# 1                                    29
# 2                                   138
# 3                                    41
# 4                                    41
# ...                                 ...
# 6003                                 43
# 6004                                  4
# 6005                                 10
# 6006                                 29
# 6007                                 18
#
#       Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  Prices  \
# 0                                              2             9.6  1418.0
# 1                                              7             8.8  1584.0
# 2                                              1            10.0  2259.0
# 3                                              1             7.9  2068.0
# 4                                              4             7.9  1352.0
# ...                                          ...             ...     ...
# 6003                                          13             9.6  1347.0
# 6004                                          10             7.9  2068.0
# 6005                                           1            10.0  1607.0
# 6006                                          15             9.2  1904.0
# 6007                                           1             9.6  1314.0
#
#                      Descriptions  \
# 0                    1 double bed
# 1              Multiple bed types
# 2        1 extra-large double bed
# 3     Beds: 1 double or 2 singles
# 4                    1 double bed
# ...                           ...
# 6003  Beds: 1 double or 2 singles
# 6004  Beds: 1 double or 2 singles
# 6005  Beds: 1 double or 2 singles
# 6006  Beds: 1 double or 2 singles
# 6007  Beds: 1 double or 2 singles
#
#                                       Full_Descriptions Sentiment  \
# 0     Featuring a seasonal rooftop plunge pool with ...  Positive
# 1     Barcelona Center is 400 metres from Barcelona’...  Positive
# 2     There is a gym and a rooftop chill-out terrace...  Positive
# 3     The Petit Palace Boqueria Garden is set in a h...  Positive
# 4     The Hotel Ronda Lesseps is a quiet and familia...  Positive
# ...                                                 ...       ...
# 6003  This motorcycle-friendly hotel is 3 Metro stop...  Positive
# 6004  The Petit Palace Boqueria Garden is set in a h...  Negative
# 6005  This stylish design hotel is located 150 metre...  Negative
# 6006  Offering an outdoor swimming pool, Olivia Balm...  Positive
# 6007  Located in Barcelona’s Eixample district, this...  Negative
#
#       Hotel_Recommendation Reviewer_Score_Binned Price_Binned
# 0                        1                  High   Affordable
# 1                        1                  High   Affordable
# 2                        1                  High    Expensive
# 3                        0                Medium    Expensive
# 4                        0                Medium   Affordable
# ...                    ...                   ...          ...
# 6003                     1                  High   Affordable
# 6004                     0                Medium    Expensive
# 6005                     0                  High   Affordable
# 6006                     1                  High   Affordable
# 6007                     0                  High   Affordable
#
# [6008 rows x 14 columns]

# %%
cpt_recommendation = (
    merged_df.groupby(['Sentiment', 'Reviewer_Score_Binned', 'Price_Binned'], observed=False)
    ['Hotel_Recommendation']
    .value_counts(normalize=True)
    .unstack(fill_value=0)  # Ensures missing values are treated as 0 probabilities
)


cpt_recommendation
# Out:
# Hotel_Recommendation                                 0         1
# Sentiment Reviewer_Score_Binned Price_Binned
# Negative  Low                   Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
#           Medium                Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
#           High                  Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
# Neutral   Low                   Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
#           Medium                Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
#           High                  Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
# Positive  Low                   Affordable    1.000000  0.000000
#                                 Expensive     1.000000  0.000000
#           Medium                Affordable    0.997006  0.002994
#                                 Expensive     1.000000  0.000000
#           High                  Affordable    0.000000  1.000000
#                                 Expensive     0.000000  1.000000

# %%
group_sizes = merged_df.groupby(['Sentiment', 'Reviewer_Score_Binned', 'Price_Binned']).size()
print(group_sizes)
# Out:
# Sentiment  Reviewer_Score_Binned  Price_Binned
# Negative   Low                    Affordable       200
#                                   Expensive         70
#            Medium                 Affordable       818
#                                   Expensive        311
#            High                   Affordable       731
#                                   Expensive        389
# Neutral    Low                    Affordable         7
#                                   Expensive          1
#            Medium                 Affordable        44
#                                   Expensive         13
#            High                   Affordable        90
#                                   Expensive         39
# Positive   Low                    Affordable        22
#                                   Expensive          8
#            Medium                 Affordable       334
#                                   Expensive        106
#            High                   Affordable      1993
#                                   Expensive        832
# dtype: int64
# C:\Users\YooNi\AppData\Local\Temp\ipykernel_43696\3267387879.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_sizes = merged_df.groupby(['Sentiment', 'Reviewer_Score_Binned', 'Price_Binned']).size()

# %%
group_sizes = merged_df.groupby(['Sentiment', 'Reviewer_Score_Binned', 'Price_Binned']).size()
print(group_sizes.describe())  # Check min, max, mean sizes
print(group_sizes[group_sizes == 1])  # See if there are many groups with only 1 entry
# Out:
# count      75.000000
# mean       80.106667
# std       304.714513
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        16.000000
# max      2173.000000
# dtype: float64
# Sentiment  Reviewer_Score_Binned  Price_Binned
# Neutral    High                   Luxury          1
# Positive   Low                    Affordable      1
#            Medium                 Luxury          1
# dtype: int64
# C:\Users\YooNi\AppData\Local\Temp\ipykernel_43696\2071556944.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_sizes = merged_df.groupby(['Sentiment', 'Reviewer_Score_Binned', 'Price_Binned']).size()
